# %% [markdown]
# ## Importing Packages

# %%
import sys
# !{sys.executable} -m pip install xgboost mlflow dagshub imbalanced-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xgboost in c:\users\mohnish\appdata\roaming\python\python313\site-packages (3.4.0)
# Requirement already satisfied: mlflow in c:\users\mohnish\appdata\roaming\python\python313\site-packages (3.15.1)
# Collecting dagshub
#   Using cached dagshub-0.7.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: imbalanced-learn in c:\programdata\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (2.3.5)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (1.16.3)
# Requirement already satisfied: mlflow-skinny==3.15.1 in c:\users\mohnish\appdata\roaming\python\python313\site-packages (from mlflow) (3.15.1)
# Requirement already satisfied: mlflow-tracing==3.15.1 in c:\users\mohnish\appdata\roaming\python\python313\site-packages (from mlflow) (3.15.1)
# Requirement already satisfied: Flask-CORS<7 in c:\users\mohnish\appdata\roaming\python\python313\site-packages (from mlflow) (6.0.5)
# Requirement already satisfied: Flask<4 in c:\programdata\anaconda3\lib\site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: aiohttp<4,>=3.7.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow) (3.13.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\mohnish\appdata\roaming\python\python313\site-packages (from mlflow) (1.19.0)
# Requirement already satisfied: cryptography<50,>=43.0.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow) (46.0.3)
# Requirement already satisfied: docker<8,>=4.0.0 in c:\users\mohnish\appdata\roaming\python\python313\site-packages (from mlflow) (7.2.0)
# Requirement already satisfied: graphene<4 in c:\users\mohnish\appdata\roaming\python\python313\site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: huey<4,>=2.5.4 in c:\users\mohnish\appdata\roaming\python\python313\site-packages (from mlflow) (3.3.4)
# Requirement already satisfied: matplotlib<4 in c:\programdata\anaconda3\lib\site-packages (from mlflow) (3.10.6)
# Requirement already satisfied: pandas<3 in c:\programdata\anaconda3\lib\site-packages (from mlflow) (2.3.3)
# Requirement already satisfied: pyarrow<26,>=4.0.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow) (21.0.0)
# Requirement already satisfied: scikit-learn<2 in c:\programdata\anaconda3\lib\site-packages (from mlflow) (1.7.2)
# Requirement already satisfied: skops<1 in c:\users\mohnish\appdata\roaming\python\python313\site-packages (from mlflow) (0.14.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow) (2.0.43)
# Requirement already satisfied: waitress<4 in c:\users\mohnish\appdata\roaming\python\python313\site-packages (from mlflow) (3.0.2)
# Requirement already satisfied: cachetools<8,>=5.0.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow-skinny==3.15.1->mlflow) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow-skinny==3.15.1->mlflow) (8.2.1)
# Requirement already satisfied: cloudpickle<4 in c:\programdata\anaconda3\lib\site-packages (from mlflow-skinny==3.15.1->mlflow) (3.1.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in c:\users\mohnish\appdata\roaming\python\python313\site-packages (from mlflow-skinny==3.15.1->mlflow) (0.125.0)
# Requirement already satisfied: fastapi<1 in c:\users\mohnish\appdata\roaming\python\python313\site-packages (from mlflow-skinny==3.15.1->mlflow) (0.141.1)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\programdata\anaconda3\lib\site-packages (from mlflow-skinny==3.15.1->mlflow) (3.1.45)
# Requirement already satisfied: importlib_metadata!=4.7.0,<10,>=3.7.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow-skinny==3.15.1->mlflow) (8.7.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in c:\users\mohnish\appdata\roaming\python\python313\site-packages (from mlflow-skinny==3.15.1->mlflow) (1.44.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in c:\users\mohnish\appdata\roaming\python\python313\site-packages (from mlflow-skinny==3.15.1->mlflow) (1.44.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in c:\users\mohnish\appdata\roaming\python\python313\site-packages (from mlflow-skinny==3.15.1->mlflow) (1.44.0)
# Requirement already satisfied: packaging<27 in c:\programdata\anaconda3\lib\site-packages (from mlflow-skinny==3.15.1->mlflow) (25.0)
# Requirement already satisfied: protobuf<8,>=3.12.0 in c:\users\mohnish\appdata\roaming\python\python313\site-packages (from mlflow-skinny==3.15.1->mlflow) (6.33.6)
# Requirement already satisfied: pydantic<3,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow-skinny==3.15.1->mlflow) (2.12.4)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow-skinny==3.15.1->mlflow) (1.1.0)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\programdata\anaconda3\lib\site-packages (from mlflow-skinny==3.15.1->mlflow) (6.0.3)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\programdata\anaconda3\lib\site-packages (from mlflow-skinny==3.15.1->mlflow) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\mohnish\appdata\roaming\python\python313\site-packages (from mlflow-skinny==3.15.1->mlflow) (0.5.5)
# Requirement already satisfied: starlette<2 in c:\users\mohnish\appdata\roaming\python\python313\site-packages (from mlflow-skinny==3.15.1->mlflow) (1.4.1)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow-skinny==3.15.1->mlflow) (4.15.0)
# Requirement already satisfied: uvicorn<1 in c:\users\mohnish\appdata\roaming\python\python313\site-packages (from mlflow-skinny==3.15.1->mlflow) (0.52.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (1.22.0)
# Requirement already satisfied: Mako in c:\users\mohnish\appdata\roaming\python\python313\site-packages (from alembic!=1.10.0,<2->mlflow) (1.4.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click<9,>=7.0->mlflow-skinny==3.15.1->mlflow) (0.4.6)
# Requirement already satisfied: cffi>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from cryptography<50,>=43.0.0->mlflow) (2.0.0)
# Requirement already satisfied: google-auth~=2.0 in c:\users\mohnish\appdata\roaming\python\python313\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.15.1->mlflow) (2.56.3)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\programdata\anaconda3\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.15.1->mlflow) (2.5.0)
# Requirement already satisfied: pywin32>=304 in c:\programdata\anaconda3\lib\site-packages (from docker<8,>=4.0.0->mlflow) (311)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\programdata\anaconda3\lib\site-packages (from fastapi<1->mlflow-skinny==3.15.1->mlflow) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\mohnish\appdata\roaming\python\python313\site-packages (from fastapi<1->mlflow-skinny==3.15.1->mlflow) (0.0.5)
# Requirement already satisfied: blinker>=1.9.0 in c:\programdata\anaconda3\lib\site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\programdata\anaconda3\lib\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\programdata\anaconda3\lib\site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\programdata\anaconda3\lib\site-packages (from Flask<4->mlflow) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\programdata\anaconda3\lib\site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\programdata\anaconda3\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.15.1->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\programdata\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.15.1->mlflow) (4.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.15.1->mlflow) (0.4.2)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\mohnish\appdata\roaming\python\python313\site-packages (from graphene<4->mlflow) (3.2.11)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\mohnish\appdata\roaming\python\python313\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in c:\programdata\anaconda3\lib\site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in c:\programdata\anaconda3\lib\site-packages (from importlib_metadata!=4.7.0,<10,>=3.7.0->mlflow-skinny==3.15.1->mlflow) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (3.2.5)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.65b0 in c:\users\mohnish\appdata\roaming\python\python313\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.15.1->mlflow) (0.65b0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.15.1->mlflow) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.15.1->mlflow) (2.41.5)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.15.1->mlflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.15.1->mlflow) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.15.1->mlflow) (2025.11.12)
# Requirement already satisfied: joblib>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (3.5.0)
# Requirement already satisfied: prettytable>=3.9 in c:\users\mohnish\appdata\roaming\python\python313\site-packages (from skops<1->mlflow) (3.18.0)
# Requirement already satisfied: greenlet>=1 in c:\programdata\anaconda3\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.2.4)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\programdata\anaconda3\lib\site-packages (from starlette<2->mlflow-skinny==3.15.1->mlflow) (4.10.0)
# Requirement already satisfied: sniffio>=1.1 in c:\programdata\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette<2->mlflow-skinny==3.15.1->mlflow) (1.3.0)
# Requirement already satisfied: h11>=0.8 in c:\programdata\anaconda3\lib\site-packages (from uvicorn<1->mlflow-skinny==3.15.1->mlflow) (0.16.0)
# Requirement already satisfied: appdirs>=1.4.4 in c:\programdata\anaconda3\lib\site-packages (from dagshub) (1.4.4)
# Requirement already satisfied: httpx>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from dagshub) (0.28.1)
# Requirement already satisfied: rich>=13.1.0 in c:\programdata\anaconda3\lib\site-packages (from dagshub) (14.2.0)
# Collecting dacite~=1.6.0 (from dagshub)
#   Using cached dacite-1.6.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: tenacity>=8.2.2 in c:\programdata\anaconda3\lib\site-packages (from dagshub) (9.1.2)
# Collecting gql[requests] (from dagshub)
#   Using cached gql-4.0.0-py3-none-any.whl.metadata (10 kB)
# Collecting dataclasses-json (from dagshub)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting treelib>=1.6.4 (from dagshub)
#   Using cached treelib-1.8.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pathvalidate>=3.0.0 (from dagshub)
#   Using cached pathvalidate-3.3.1-py3-none-any.whl.metadata (12 kB)
# Collecting boto3 (from dagshub)
#   Using cached boto3-1.43.66-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: semver in c:\programdata\anaconda3\lib\site-packages (from dagshub) (3.0.4)
# Collecting dagshub-annotation-converter>=0.2.0 (from dagshub)
#   Using cached dagshub_annotation_converter-0.2.2-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=2.0.0->cryptography<50,>=43.0.0->mlflow) (2.23)
# Requirement already satisfied: lxml in c:\programdata\anaconda3\lib\site-packages (from dagshub-annotation-converter>=0.2.0->dagshub) (5.3.0)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.23.0->dagshub) (1.0.9)
# Requirement already satisfied: wcwidth>=0.3.5 in c:\users\mohnish\appdata\roaming\python\python313\site-packages (from prettytable>=3.9->skops<1->mlflow) (0.8.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\programdata\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.15.1->mlflow) (0.6.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\programdata\anaconda3\lib\site-packages (from rich>=13.1.0->dagshub) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from rich>=13.1.0->dagshub) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\programdata\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.1.0->dagshub) (0.1.2)
# Collecting botocore<1.44.0,>=1.43.66 (from boto3->dagshub)
#   Using cached botocore-1.43.66-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\programdata\anaconda3\lib\site-packages (from boto3->dagshub) (1.0.1)
# Collecting s3transfer<0.20.0,>=0.19.0 (from boto3->dagshub)
#   Using cached s3transfer-0.19.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->dagshub)
#   Using cached marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json->dagshub)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->dagshub) (1.0.0)
# Collecting backoff<3.0,>=1.11.1 (from gql[requests]->dagshub)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests_toolbelt<2,>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from gql[requests]->dagshub) (1.0.0)
# Using cached dagshub-0.7.1-py3-none-any.whl (273 kB)
# Using cached dacite-1.6.0-py3-none-any.whl (12 kB)
# Using cached dagshub_annotation_converter-0.2.2-py3-none-any.whl (68 kB)
# Using cached pathvalidate-3.3.1-py3-none-any.whl (24 kB)
# Using cached treelib-1.8.0-py3-none-any.whl (30 kB)
# Using cached boto3-1.43.66-py3-none-any.whl (140 kB)
# Using cached botocore-1.43.66-py3-none-any.whl (15.6 MB)
# Using cached s3transfer-0.19.2-py3-none-any.whl (90 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached gql-4.0.0-py3-none-any.whl (89 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Installing collected packages: typing-inspect, treelib, pathvalidate, marshmallow, dacite, backoff, gql, dataclasses-json, botocore, s3transfer, dagshub-annotation-converter, boto3, dagshub
#
#    --- ------------------------------------  1/13 [treelib]
#    --- ------------------------------------  1/13 [treelib]
#    --- ------------------------------------  1/13 [treelib]
#    ------ ---------------------------------  2/13 [pathvalidate]
#    ------ ---------------------------------  2/13 [pathvalidate]
#    ------ ---------------------------------  2/13 [pathvalidate]
#    --------- ------------------------------  3/13 [marshmallow]
#    --------- ------------------------------  3/13 [marshmallow]
#    --------- ------------------------------  3/13 [marshmallow]
#    ------------ ---------------------------  4/13 [dacite]
#    ------------ ---------------------------  4/13 [dacite]
#    ------------ ---------------------------  4/13 [dacite]
#    --------------- ------------------------  5/13 [backoff]
#    ------------------ ---------------------  6/13 [gql]
#    ------------------ ---------------------  6/13 [gql]
#    ------------------ ---------------------  6/13 [gql]
#    ------------------ ---------------------  6/13 [gql]
#    ------------------ ---------------------  6/13 [gql]
#    ------------------ ---------------------  6/13 [gql]
#    ------------------ ---------------------  6/13 [gql]
#    ------------------ ---------------------  6/13 [gql]
#    ------------------ ---------------------  6/13 [gql]
#    ------------------ ---------------------  6/13 [gql]
#    ------------------ ---------------------  6/13 [gql]
#    --------------------- ------------------  7/13 [dataclasses-json]
#    --------------------- ------------------  7/13 [dataclasses-json]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    ------------------------ ---------------  8/13 [botocore]
#    --------------------------- ------------  9/13 [s3transfer]
#    --------------------------- ------------  9/13 [s3transfer]
#    --------------------------- ------------  9/13 [s3transfer]
#    --------------------------- ------------  9/13 [s3transfer]
#    ------------------------------ -------- 10/13 [dagshub-annotation-converter]
#    ------------------------------ -------- 10/13 [dagshub-annotation-converter]
#    ------------------------------ -------- 10/13 [dagshub-annotation-converter]
#    ------------------------------ -------- 10/13 [dagshub-annotation-converter]
#    ------------------------------ -------- 10/13 [dagshub-annotation-converter]
#    ------------------------------ -------- 10/13 [dagshub-annotation-converter]
#    ------------------------------ -------- 10/13 [dagshub-annotation-converter]
#    ------------------------------ -------- 10/13 [dagshub-annotation-converter]
#    ------------------------------ -------- 10/13 [dagshub-annotation-converter]
#    ------------------------------ -------- 10/13 [dagshub-annotation-converter]
#    ------------------------------ -------- 10/13 [dagshub-annotation-converter]
#    ------------------------------ -------- 10/13 [dagshub-annotation-converter]
#    --------------------------------- ------ 11/13 [boto3]
#    --------------------------------- ------ 11/13 [boto3]
#    --------------------------------- ------ 11/13 [boto3]
#    --------------------------------- ------ 11/13 [boto3]
#    --------------------------------- ------ 11/13 [boto3]
#    --------------------------------- ------ 11/13 [boto3]
#    --------------------------------- ------ 11/13 [boto3]
#    --------------------------------- ------ 11/13 [boto3]
#    --------------------------------- ------ 11/13 [boto3]
#    --------------------------------- ------ 11/13 [boto3]
#    ------------------------------------ --- 12/13 [dagshub]
#    ------------------------------------ --- 12/13 [dagshub]
#    ------------------------------------ --- 12/13 [dagshub]
#    ------------------------------------ --- 12/13 [dagshub]
#    ------------------------------------ --- 12/13 [dagshub]
#    ------------------------------------ --- 12/13 [dagshub]
#    ------------------------------------ --- 12/13 [dagshub]
#    ------------------------------------ --- 12/13 [dagshub]
#    ------------------------------------ --- 12/13 [dagshub]
#    ------------------------------------ --- 12/13 [dagshub]
#    ------------------------------------ --- 12/13 [dagshub]
#    ------------------------------------ --- 12/13 [dagshub]
#    ------------------------------------ --- 12/13 [dagshub]
#    ------------------------------------ --- 12/13 [dagshub]
#    ------------------------------------ --- 12/13 [dagshub]
#    ------------------------------------ --- 12/13 [dagshub]
#    ------------------------------------ --- 12/13 [dagshub]
#    ------------------------------------ --- 12/13 [dagshub]
#    ------------------------------------ --- 12/13 [dagshub]
#    ------------------------------------ --- 12/13 [dagshub]
#    ------------------------------------ --- 12/13 [dagshub]
#    ------------------------------------ --- 12/13 [dagshub]
#    ---------------------------------------- 13/13 [dagshub]
#
# Successfully installed backoff-2.2.1 boto3-1.43.66 botocore-1.43.66 dacite-1.6.0 dagshub-0.7.1 dagshub-annotation-converter-0.2.2 dataclasses-json-0.6.7 gql-4.0.0 marshmallow-3.26.2 pathvalidate-3.3.1 s3transfer-0.19.2 treelib-1.8.0 typing-inspect-0.9.0
#   WARNING: The script gql-cli.exe is installed in 'C:\Users\Mohnish\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script dagshub.exe is installed in 'C:\Users\Mohnish\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.25.0 requires botocore<1.40.50,>=1.40.46, but you have botocore 1.43.66 which is incompatible.

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np

from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

from xgboost import XGBRegressor

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score,
)

import mlflow
import mlflow.sklearn
import mlflow.xgboost

import dagshub
import os

# %% [markdown]
# ## DagsHub MLflow Setup

# %%
dagshub.init(
    repo_owner="mohnish1234-git",
    repo_name="dev_ops_056",
    mlflow=True
)
# Out:
# Initialized MLflow to track repo "mohnish1234-git/dev_ops_056"
# Repository mohnish1234-git/dev_ops_056 initialized!

# %%
mlflow.set_experiment(
    "Boston Housing Regression PBLM 1"
)
# Out:
# 2026/08/07 11:19:20 INFO mlflow.tracking.fluent: Experiment with name 'Boston Housing Regression PBLM 1' does not exist. Creating a new experiment.
# <Experiment: artifact_location='mlflow-artifacts:/a5e41f61baf644e18d14388d5912171f', creation_time=1786081761730, effective_trace_archival_retention=None, experiment_id='1', last_update_time=1786081761730, lifecycle_stage='active', name='Boston Housing Regression PBLM 1', tags={}, trace_location=None, workspace='default'>

# %% [markdown]
# ## Data Loading and Processing

# %%
import pandas as pd

df = pd.read_csv("BostonHousing.csv")

X = df.drop("medv", axis=1)
y = df["medv"]

print(X.shape)
print(y.shape)
# Out:
# (506, 13)
# (506,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42
)

# %%
X_train_res = X_train.copy()
y_train_res = y_train.copy()

print(X_train_res.shape)
print(y_train_res.shape)
# Out:
# (354, 13)
# (354,)

# %% [markdown]
# ## Build Models

# %%
models = [
    (
        "Linear Regression",
        LinearRegression(),
        X_train,
        y_train
    ),
    (
        "Random Forest Regressor",
        RandomForestRegressor(
            n_estimators=100,
            max_depth=5,
            random_state=42
        ),
        X_train,
        y_train
    ),
    (
        "XGBoost Regressor",
        XGBRegressor(
            random_state=42
        ),
        X_train,
        y_train
    )
]

# %%
print(df.isnull().sum())
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
reports = []
trained_models = []

for model_name, model, X_tr, y_tr in models:
    model.fit(X_tr, y_tr)

    predictions = model.predict(X_test)

    mae = mean_absolute_error(y_test, predictions)
    mse = mean_squared_error(y_test, predictions)
    rmse = mse ** 0.5
    r2 = r2_score(y_test, predictions)

    report = {
        "MAE": mae,
        "MSE": mse,
        "RMSE": rmse,
        "R2": r2
    }

    reports.append(report)
    trained_models.append(model)

    print("=" * 50)
    print(model_name)
    print("=" * 50)
    print(f"MAE  : {mae:.4f}")
    print(f"MSE  : {mse:.4f}")
    print(f"RMSE : {rmse:.4f}")
    print(f"R2   : {r2:.4f}")
# Out:
# ==================================================
# Linear Regression
# ==================================================
# MAE  : 3.1627
# MSE  : 21.5174
# RMSE : 4.6387
# R2   : 0.7112
# ==================================================
# Random Forest Regressor
# ==================================================
# MAE  : 2.2751
# MSE  : 11.1488
# RMSE : 3.3390
# R2   : 0.8504
# ==================================================
# XGBoost Regressor
# ==================================================
# MAE  : 2.0600
# MSE  : 9.2880
# RMSE : 3.0476
# R2   : 0.8754

# %% [markdown]
# ## Log All Experiments to DagsHub

# %%
for i, (model_name, model, _, _) in enumerate(models):
    report = reports[i]

    with mlflow.start_run(run_name=model_name):

        # Log model name
        mlflow.log_param(
            "Model",
            model_name
        )

        # Log hyperparameters
        mlflow.log_params(
            model.get_params()
        )

        # Log regression metrics
        mlflow.log_metric(
            "MAE",
            report["MAE"]
        )

        mlflow.log_metric(
            "MSE",
            report["MSE"]
        )

        mlflow.log_metric(
            "RMSE",
            report["RMSE"]
        )

        mlflow.log_metric(
            "R2",
            report["R2"]
        )

        # Log model
        if "XGBoost" in model_name:

            mlflow.xgboost.log_model(
                model,
                "model"
            )

        else:

            mlflow.sklearn.log_model(
                model,
                "model"
            )

print("Experiments logged!")
# Out:
# 2026/08/07 11:19:33 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Linear Regression at: https://dagshub.com/mohnish1234-git/dev_ops_056.mlflow/#/experiments/1/runs/299d5c87f7ea4880a94f75afec2d7ddb
# 🧪 View experiment at: https://dagshub.com/mohnish1234-git/dev_ops_056.mlflow/#/experiments/1
# 2026/08/07 11:20:31 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Random Forest Regressor at: https://dagshub.com/mohnish1234-git/dev_ops_056.mlflow/#/experiments/1/runs/55922b0ef39c4afab94a9d01f78833b8
# 🧪 View experiment at: https://dagshub.com/mohnish1234-git/dev_ops_056.mlflow/#/experiments/1
# 2026/08/07 11:21:29 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run XGBoost Regressor at: https://dagshub.com/mohnish1234-git/dev_ops_056.mlflow/#/experiments/1/runs/ca041b8a1f1748cea163eb0894bd4652
# 🧪 View experiment at: https://dagshub.com/mohnish1234-git/dev_ops_056.mlflow/#/experiments/1
# Experiments logged!

# %% [markdown]
# ## Best Model and Reg to DH

# %%
best_index = np.argmax(
    [
        r["R2"]
        for r in reports
    ]
)

best_model_name = models[best_index][0]

best_model = trained_models[best_index]

best_report = reports[best_index]

print("Best Model:", best_model_name)
print("R2 Score:", best_report["R2"])
# Out:
# Best Model: XGBoost Regressor
# R2 Score: 0.8753514389204832

# %%
with mlflow.start_run(
    run_name=f"Champion_{best_model_name}"
) as run:

    mlflow.log_param(
        "Model",
        best_model_name
    )

    mlflow.log_metric(
        "MAE",
        best_report["MAE"]
    )

    mlflow.log_metric(
        "MSE",
        best_report["MSE"]
    )

    mlflow.log_metric(
        "RMSE",
        best_report["RMSE"]
    )

    mlflow.log_metric(
        "R2",
        best_report["R2"]
    )

    if "XGBoost" in best_model_name:

        mlflow.xgboost.log_model(
            best_model,
            "model",
            registered_model_name="Boston_Housing_Best_Model"
        )

    else:

        mlflow.sklearn.log_model(
            best_model,
            "model",
            registered_model_name="Boston_Housing_Best_Model"
        )

    run_id = run.info.run_id

print(run_id)
# Out:
# 2026/08/07 11:22:09 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Successfully registered model 'Boston_Housing_Best_Model'.
# 2026/08/07 11:22:44 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: Boston_Housing_Best_Model, version 1
# Created version '1' of model 'Boston_Housing_Best_Model'.
# 🏃 View run Champion_XGBoost Regressor at: https://dagshub.com/mohnish1234-git/dev_ops_056.mlflow/#/experiments/1/runs/fca320bab56d44a780a2e6dc64c03de8
# 🧪 View experiment at: https://dagshub.com/mohnish1234-git/dev_ops_056.mlflow/#/experiments/1
# fca320bab56d44a780a2e6dc64c03de8
